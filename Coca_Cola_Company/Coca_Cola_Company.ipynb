# %% [markdown]
# <a href="https://colab.research.google.com/github/mietekdom/Data_Science_Cases/blob/master/Coca_Cola_Company/Coca_Cola_Company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly
plotly.__version__
# Out:
# '4.4.1'

# %%
import plotly.express as px

# %%
def fetch_financial_data(company='KO'): # Coaca-Cola Company
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
df = df.reset_index()
df.head()
# Out:
#         Date   Open     High    Low  Close    Volume
# 0 2020-09-08  50.93  51.0400  49.36  49.81  17776745
# 1 2020-09-04  50.94  51.4650  50.28  51.04  21019545
# 2 2020-09-03  51.40  52.1378  50.10  50.48  22289383
# 3 2020-09-02  49.36  51.3600  49.36  51.19  26332630
# 4 2020-09-01  49.31  49.3500  48.83  49.12  12590434

# %%
px.area(data_frame=df, x='Date', y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b1c00cf8-de3c-4881-8e4b-443a3be6cf6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b1c00cf8-de3c-4881-8e4b-443a3be6cf6e")) {
#                     Plotly.newPlot(
#                         'b1c00cf8-de3c-4881-8e4b-443a3be6cf6e',
# ...

# %%
px.area(data_frame=df, x='Date', y='Close', log_y=True, title='Wykres spółki Cocal-Cola')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="96b05af6-528f-4bc8-a189-7221ab938c3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("96b05af6-528f-4bc8-a189-7221ab938c3b")) {
#                     Plotly.newPlot(
#                         '96b05af6-528f-4bc8-a189-7221ab938c3b',
# ...
